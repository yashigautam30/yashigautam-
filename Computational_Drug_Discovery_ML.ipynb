# %% [markdown]
# <a href="https://colab.research.google.com/github/yashigautam30/yashigautam-/blob/main/Computational_Drug_Discovery_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.33.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd

# %%
from chembl_webresource_client.new_client import new_client

# %%
# target search for coronavirus
target = new_client.target
target_query = target.search("coronavirus")
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 7                                                 []
# 8  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 9                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                                 Murine coronavirus
# 4                             Human coronavirus 229E
# 5                             Human coronavirus OC43
# 6                                   SARS coronavirus
# 7  Middle East respiratory syndrome-related coron...
# 8                                   SARS coronavirus
# 9    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   14.0
# 2                                 Feline coronavirus   14.0
# 3                                 Murine coronavirus   14.0
# 4                             Human coronavirus 229E   12.0
# 5                             Human coronavirus OC43   12.0
# 6                SARS coronavirus 3C-like proteinase   10.0
# 7  Middle East respiratory syndrome-related coron...    9.0
# 8                          Replicase polyprotein 1ab    4.0
# 9                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False    CHEMBL5209664
# 4               False     CHEMBL613837
# 5               False    CHEMBL5209665
# 6               False       CHEMBL3927
# 7               False    CHEMBL4296578
# 8               False       CHEMBL5118
# 9               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM   694005
# 4                                                 []        ORGANISM    11137
# 5                                                 []        ORGANISM    31631
# 6  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 7                                                 []        ORGANISM  1335626
# 8  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859
# 9  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_types="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(6)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1480934                  []
# 1        None             None      1480935                  []
# 2        None             None      1480936                  []
# 3        None             None      1481061                  []
# 4        None             None      1481062                  []
# 5        None             None      1481063                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL831837  In vitro percent inhibition against SARS coron...
# 1    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 3    CHEMBL830868  In vitro inhibitory concentration against SARS...
# 4    CHEMBL832053  In vitro percent inhibition against SARS coron...
# 5    CHEMBL831837  In vitro percent inhibition against SARS coron...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000201  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000201  ...
# 5          B                    None                   None  BAO_0000201  ...
#
#     target_organism                     target_pref_name target_tax_id  \
# 0  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 3  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 4  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 5  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#   text_value  toid        type units    uo_units upper_value value
# 0       None  None  Inhibition     %  UO_0000187        None  25.0
# 1       None  None        IC50    uM  UO_0000065        None   7.2
# 2       None  None        IC50    uM  UO_0000065        None   9.4
# 3       None  None        IC50    uM  UO_0000065        None  13.5
# 4       None  None  Inhibition     %  UO_0000187        None  13.0
# 5       None  None  Inhibition     %  UO_0000187        None  13.0
#
# [6 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['Inhibition', 'IC50', 'kinact', 'T1/2', 'Activity', 'Ki', 'Kd'],
#       dtype=object)

# %%
df.to_csv('bioactivity_data.csv',index = False)

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
ls "/content/gdrive/My Drive/Colab Notebooks/"
# Out:
# '21 11 23 operations.ipynb'   Untitled2.ipynb        Untitled4.ipynb   Untitled7.ipynb
#  Untitled0.ipynb             'Untitled3 (1).ipynb'   Untitled5.ipynb   Untitled8.ipynb
#  Untitled1.ipynb              Untitled3.ipynb        Untitled6.ipynb

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 157
# -rw------- 1 root root 160083 Feb 24 21:12 bioactivity_data.csv

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,1480934,[],CHEMBL831837,In vitro percent inhibition against SARS coronavirus main protease (SARS CoV 3C-like protease) at 20 uM,B,,,BAO_0000201,BAO_0000357,single protein format,Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C(N)=O)ccc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,,CHEMBL372889,,CHEMBL372889,,0,http://qudt.org/vocab/unit#Percent,384102,=,1,1,=,,Inhibition,%,,25.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,Inhibition,%,UO_0000187,,25.0
# ,,1480935,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '18.28', 'le': '0.33', 'lle': '3.25', 'sei': '5.90'}",CHEMBL187579,,CHEMBL187579,5.14,0,http://www.openphacts.org/units/Nanomolar,384103,=,1,1,=,,IC50,nM,,7200.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,7.2
# ,,1480936,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '12.10', 'le': '0.33', 'lle': '1.22', 'sei': '13.45'}",CHEMBL188487,,CHEMBL188487,5.03,0,http://www.openphacts.org/units/Nanomolar,383984,=,1,1,=,,IC50,nM,,9400.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,9.4
# ,,1481061,[],CHEMBL830868,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease) at 20 uM,B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '11.56', 'le': '0.29', 'lle': '2.21', 'sei': '8.72'}",CHEMBL185698,,CHEMBL185698,4.87,0,http://www.openphacts.org/units/Nanomolar,384106,=,1,1,=,,IC50,nM,,13500.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,13.5
# ,,1481062,[],CHEMBL832053,In vitro percent inhibition against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000201,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3o2)c2ccc(I)cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,,CHEMBL188484,,CHEMBL188484,,0,http://qudt.org/vocab/unit#Percent,383987,=,1,1,=,,Inhibition,%,,13.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,Inhibition,%,UO_0000187,,13.0
# ,,1481063,[],CHEMBL831837,In vitro percent inhibition against SARS coronavirus main protease (SARS CoV 3C-like protease) at 20 uM,B,,,BAO_0000201,BAO_0000357,single protein format,COc1ccc2c(c1)C(=O)C(=O)N2Cc1cc2ccccc2o1,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,,CHEMBL362781,,CHEMBL362781,,0,http://qudt.org/vocab/unit#Percent,383988,=,1,1,=,,Inhibition,%,,13.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,Inhibition,%,UO_0000187,,13.0
# ,,1481064,[],CHEMBL831837,In vitro percent inhibition against SARS coronavirus main protease (SARS CoV 3C-like protease) at 20 uM,B,,,BAO_0000201,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3o2)c2ccc([N+](=O)[O-])cc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,,CHEMBL191322,,CHEMBL191322,,0,http://qudt.org/vocab/unit#Percent,384074,=,1,1,=,,Inhibition,%,,24.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,Inhibition,%,UO_0000187,,24.0
# ,,1481065,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21,,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '16.64', 'le': '0.32', 'lle': '1.25', 'sei': '13.06'}",CHEMBL426082,,CHEMBL426082,4.88,0,http://www.openphacts.org/units/Nanomolar,384075,=,1,1,=,,IC50,nM,,13110.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,13.11
# ,,1481066,[],CHEMBL829584,In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease),B,,,BAO_0000190,BAO_0000357,single protein format,O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-],,,CHEMBL1139624,Bioorg Med Chem Lett,2005,"{'bei': '16.84', 'le': '0.32', 'lle': '2.16', 'sei': '7.08'}",CHEMBL187717,,CHEMBL187717,5.70,0,http://www.openphacts.org/units/Nanomolar,384234,=,1,1,=,,IC50,nM,,2000.0,CHEMBL3927,SARS coronavirus,SARS coronavirus 3C-like proteinase,227859,,,IC50,uM,UO_0000065,,2.0

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 306                                               None             None
# 307                                               None             None
# 308                                               None             None
# 329  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 330  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# 0        1480934                  []    CHEMBL831837
# 1        1480935                  []    CHEMBL829584
# 2        1480936                  []    CHEMBL829584
# 3        1481061                  []    CHEMBL830868
# 4        1481062                  []    CHEMBL832053
# ..           ...                 ...             ...
# 306     12041509                  []   CHEMBL2150313
# 307     12041510                  []   CHEMBL2150313
# 308     12041511                  []   CHEMBL2150313
# 329     24672242                  []   CHEMBL5100307
# 330     24672243                  []   CHEMBL5100307
#
#                                      assay_description assay_type  \
# 0    In vitro percent inhibition against SARS coron...          B
# 1    In vitro inhibitory concentration against SARS...          B
# 2    In vitro inhibitory concentration against SARS...          B
# 3    In vitro inhibitory concentration against SARS...          B
# 4    In vitro percent inhibition against SARS coron...          B
# ..                                                 ...        ...
# 306  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 307  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 308  Inhibition of SARS-CoV PLpro expressed in Esch...          B
# 329  Binding affinity to 15N-labelled His6-tagged S...          B
# 330  Binding affinity to 15N-labelled His6-tagged S...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000201  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000201  ...
# ..                      ...                    ...          ...  ...
# 306                    None                   None  BAO_0000190  ...
# 307                    None                   None  BAO_0000190  ...
# 308                    None                   None  BAO_0000190  ...
# 329                    None                   None  BAO_0000034  ...
# 330                    None                   None  BAO_0000034  ...
#
#       target_organism                     target_pref_name target_tax_id  \
# 0    SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 1    SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 2    SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 3    SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 4    SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# ..                ...                                  ...           ...
# 306  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 307  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 308  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 329  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
# 330  SARS coronavirus  SARS coronavirus 3C-like proteinase        227859
#
#     text_value  toid        type units    uo_units upper_value value
# 0         None  None  Inhibition     %  UO_0000187        None  25.0
# 1         None  None        IC50    uM  UO_0000065        None   7.2
# 2         None  None        IC50    uM  UO_0000065        None   9.4
# 3         None  None        IC50    uM  UO_0000065        None  13.5
# 4         None  None  Inhibition     %  UO_0000187        None  13.0
# ..         ...   ...         ...   ...         ...         ...   ...
# 306       None  None        IC50    uM  UO_0000065        None  11.5
# 307       None  None        IC50    uM  UO_0000065        None  10.7
# 308       None  None        IC50    uM  UO_0000065        None  78.9
# 329       None  None          Kd    mM  UO_0000065        None   1.0
# 330       None  None          Kd    mM  UO_0000065        None  0.22
#
# [289 rows x 46 columns]

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
df2.molecule_chembl_id
# Out:
# 0      CHEMBL372889
# 1      CHEMBL187579
# 2      CHEMBL188487
# 3      CHEMBL185698
# 4      CHEMBL188484
#            ...
# 306    CHEMBL363535
# 307    CHEMBL227075
# 308     CHEMBL45830
# 329      CHEMBL1071
# 330       CHEMBL509
# Name: molecule_chembl_id, Length: 289, dtype: object

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL372889',
#  'CHEMBL187579',
#  'CHEMBL188487',
#  'CHEMBL185698',
#  'CHEMBL188484',
#  'CHEMBL362781',
#  'CHEMBL191322',
#  'CHEMBL426082',
#  'CHEMBL187717',
#  'CHEMBL363243',
#  'CHEMBL365134',
#  'CHEMBL365677',
#  'CHEMBL188811',
#  'CHEMBL187598',
#  'CHEMBL190743',
#  'CHEMBL365469',
#  'CHEMBL362493',
#  'CHEMBL188983',
#  'CHEMBL365242',
#  'CHEMBL190155',
#  'CHEMBL191575',
#  'CHEMBL364253',
#  'CHEMBL370098',
#  'CHEMBL188961',
#  'CHEMBL187600',
#  'CHEMBL370923',
#  'CHEMBL198359',
#  'CHEMBL198359',
#  'CHEMBL194398',
#  'CHEMBL194398',
#  'CHEMBL194398',
#  'CHEMBL196635',
#  'CHEMBL196635',
#  'CHEMBL196635',
#  'CHEMBL197193',
#  'CHEMBL197193',
#  'CHEMBL196253',
#  'CHEMBL196909',
#  'CHEMBL445656',
#  'CHEMBL202391',
#  'CHEMBL196804',
#  'CHEMBL381454',
#  'CHEMBL382936',
#  'CHEMBL371081',
#  'CHEMBL370643',
#  'CHEMBL198908',
#  'CHEMBL198907',
#  'CHEMBL380569',
#  'CHEMBL197491',
#  'CHEMBL201935',
#  'CHEMBL198521',
#  'CHEMBL370363',
#  'CHEMBL382725',
#  'CHEMBL196963',
#  'CHEMBL383562',
#  'CHEMBL200433',
#  'CHEMBL198753',
#  'CHEMBL199267',
#  'CHEMBL200073',
#  'CHEMBL197657',
#  'CHEMBL200464',
#  'CHEMBL200722',
#  'CHEMBL382759',
#  'CHEMBL370196',
#  'CHEMBL425206',
#  'CHEMBL198854',
#  'CHEMBL199026',
#  'CHEMBL381440',
#  'CHEMBL383571',
#  'CHEMBL197012',
#  'CHEMBL198858',
#  'CHEMBL198695',
#  'CHEMBL383786',
#  'CHEMBL440034',
#  'CHEMBL197116',
#  'CHEMBL198695',
#  'CHEMBL209287',
#  'CHEMBL325480',
#  'CHEMBL210381',
#  'CHEMBL383761',
#  'CHEMBL208034',
#  'CHEMBL379354',
#  'CHEMBL273738',
#  'CHEMBL379424',
#  'CHEMBL149556',
#  'CHEMBL210543',
#  'CHEMBL210323',
#  'CHEMBL207586',
#  'CHEMBL207585',
#  'CHEMBL64582',
#  'CHEMBL207133',
#  'CHEMBL64413',
#  'CHEMBL358279',
#  'CHEMBL348660',
#  'CHEMBL379727',
#  'CHEMBL210525',
#  'CHEMBL148483',
#  'CHEMBL383725',
#  'CHEMBL118596',
#  'CHEMBL209287',
#  'CHEMBL118596',
#  'CHEMBL383725',
#  'CHEMBL148483',
#  'CHEMBL210525',
#  'CHEMBL379727',
#  'CHEMBL348660',
#  'CHEMBL358279',
#  'CHEMBL209287',
#  'CHEMBL118596',
#  'CHEMBL383725',
#  'CHEMBL148483',
#  'CHEMBL210525',
#  'CHEMBL379727',
#  'CHEMBL348660',
#  'CHEMBL358279',
#  'CHEMBL208732',
#  'CHEMBL208732',
#  'CHEMBL210146',
#  'CHEMBL210146',
#  'CHEMBL207458',
#  'CHEMBL207458',
#  'CHEMBL207484',
#  'CHEMBL207484',
#  'CHEMBL207207',
#  'CHEMBL207207',
#  'CHEMBL210487',
#  'CHEMBL210487',
#  'CHEMBL380470',
#  'CHEMBL380470',
#  'CHEMBL210612',
#  'CHEMBL210612',
#  'CHEMBL209667',
#  'CHEMBL209667',
#  'CHEMBL210097',
#  'CHEMBL210097',
#  'CHEMBL378674',
#  'CHEMBL378674',
#  'CHEMBL210216',
#  'CHEMBL210216',
#  'CHEMBL210195',
#  'CHEMBL210195',
#  'CHEMBL210437',
#  'CHEMBL210437',
#  'CHEMBL378677',
#  'CHEMBL378677',
#  'CHEMBL210972',
#  'CHEMBL210972',
#  'CHEMBL210145',
#  'CHEMBL210145',
#  'CHEMBL377225',
#  'CHEMBL377225',
#  'CHEMBL210823',
#  'CHEMBL210823',
#  'CHEMBL207381',
#  'CHEMBL207381',
#  'CHEMBL210511',
#  'CHEMBL210511',
#  'CHEMBL210632',
#  'CHEMBL210632',
#  'CHEMBL210497',
#  'CHEMBL210497',
#  'CHEMBL208584',
#  'CHEMBL208584',
#  'CHEMBL208763',
#  'CHEMBL208763',
#  'CHEMBL209227',
#  'CHEMBL209227',
#  'CHEMBL210092',
#  'CHEMBL210092',
#  'CHEMBL377150',
#  'CHEMBL377150',
#  'CHEMBL277716',
#  'CHEMBL213543',
#  'CHEMBL212080',
#  'CHEMBL20636',
#  'CHEMBL213054',
#  'CHEMBL212454',
#  'CHEMBL213581',
#  'CHEMBL380403',
#  'CHEMBL212504',
#  'CHEMBL211969',
#  'CHEMBL384739',
#  'CHEMBL215732',
#  'CHEMBL212240',
#  'CHEMBL377253',
#  'CHEMBL215397',
#  'CHEMBL378342',
#  'CHEMBL379642',
#  'CHEMBL427404',
#  'CHEMBL212190',
#  'CHEMBL378700',
#  'CHEMBL212019',
#  'CHEMBL212399',
#  'CHEMBL215733',
#  'CHEMBL211928',
#  'CHEMBL375130',
#  'CHEMBL213580',
#  'CHEMBL214372',
#  'CHEMBL212218',
#  'CHEMBL426711',
#  'CHEMBL223377',
#  'CHEMBL375867',
#  'CHEMBL223708',
#  'CHEMBL225650',
#  'CHEMBL189362',
#  'CHEMBL221418',
#  'CHEMBL376898',
#  'CHEMBL221369',
#  'CHEMBL221368',
#  'CHEMBL375452',
#  'CHEMBL222234',
#  'CHEMBL375451',
#  'CHEMBL376023',
#  'CHEMBL426898',
#  'CHEMBL222840',
#  'CHEMBL373971',
#  'CHEMBL387355',
#  'CHEMBL225232',
#  'CHEMBL376674',
#  'CHEMBL387321',
#  'CHEMBL373784',
#  'CHEMBL221366',
#  'CHEMBL222342',
#  'CHEMBL376243',
#  'CHEMBL328441',
#  'CHEMBL222840',
#  'CHEMBL222769',
#  'CHEMBL222735',
#  'CHEMBL225511',
#  'CHEMBL376824',
#  'CHEMBL225510',
#  'CHEMBL225350',
#  'CHEMBL376673',
#  'CHEMBL221367',
#  'CHEMBL222906',
#  'CHEMBL222696',
#  'CHEMBL221929',
#  'CHEMBL223797',
#  'CHEMBL225196',
#  'CHEMBL222646',
#  'CHEMBL221720',
#  'CHEMBL221501',
#  'CHEMBL222628',
#  'CHEMBL222893',
#  'CHEMBL225515',
#  'CHEMBL222234',
#  'CHEMBL426898',
#  'CHEMBL225515',
#  'CHEMBL222769',
#  'CHEMBL222735',
#  'CHEMBL222628',
#  'CHEMBL222893',
#  'CHEMBL222234',
#  'CHEMBL187266',
#  'CHEMBL215254',
#  'CHEMBL2146517',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL187266',
#  'CHEMBL215254',
#  'CHEMBL2146517',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL541265',
#  'CHEMBL187266',
#  'CHEMBL215254',
#  'CHEMBL2146517',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL215254',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL187266',
#  'CHEMBL215254',
#  'CHEMBL2146517',
#  'CHEMBL187460',
#  'CHEMBL363535',
#  'CHEMBL227075',
#  'CHEMBL45830',
#  'CHEMBL1071',
#  'CHEMBL509']

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
selection = ["molecule_chembl_id", "canonical_smiles", "standard_value"]
df3= df2[selection]

# %%
df3
# Out:
#     molecule_chembl_id                               canonical_smiles  \
# 0         CHEMBL372889      Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C(N)=O)ccc21
# 1         CHEMBL187579         Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 2         CHEMBL188487         O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 3         CHEMBL185698        O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 4         CHEMBL188484         O=C1C(=O)N(Cc2cc3ccccc3o2)c2ccc(I)cc21
# ..                 ...                                            ...
# 306       CHEMBL363535         Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 307       CHEMBL227075  Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 308        CHEMBL45830         CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
# 329         CHEMBL1071          O=C(O)CCc1nc(-c2ccccc2)c(-c2ccccc2)o1
# 330          CHEMBL509               Cc1ccc(Cl)c(Nc2ccccc2C(=O)O)c1Cl
#
#     standard_value
# 0             25.0
# 1           7200.0
# 2           9400.0
# 3          13500.0
# 4             13.0
# ..             ...
# 306        11500.0
# 307        10700.0
# 308        78900.0
# 329      1000000.0
# 330       220000.0
#
# [289 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                           canonical_smiles  \
# 0         CHEMBL372889  Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C(N)=O)ccc21
# 1         CHEMBL187579     Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 2         CHEMBL188487     O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 3         CHEMBL185698    O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 4         CHEMBL188484     O=C1C(=O)N(Cc2cc3ccccc3o2)c2ccc(I)cc21
# ..                 ...                                        ...
# 284                NaN                                        NaN
# 285                NaN                                        NaN
# 286                NaN                                        NaN
# 287                NaN                                        NaN
# 288                NaN                                        NaN
#
#     standard_value             0
# 0             25.0        active
# 1           7200.0  intermediate
# 2           9400.0  intermediate
# 3          13500.0      inactive
# 4             13.0        active
# ..             ...           ...
# 284            NaN      inactive
# 285            NaN      inactive
# 286            NaN      inactive
# 287            NaN      inactive
# 288            NaN      inactive
#
# [298 rows x 4 columns]

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index = False)

# %%
! ls -l
# Out:
# total 208
# -rw-r--r-- 1 root root 160083 Feb 24 20:56 bioactivity_data.csv
# -rw-r--r-- 1 root root  18798 Feb 24 21:36 bioactivity_preprecessed_data.csv
# -rw-r--r-- 1 root root  18798 Feb 24 21:39 bioactivity_preprocessed_data.csv
# drwx------ 5 root root   4096 Feb 24 21:07 gdrive
# drwxr-xr-x 1 root root   4096 Feb 22 14:24 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv
